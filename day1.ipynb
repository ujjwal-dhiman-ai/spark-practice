# %%
# !pip install pandas
# Out:
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------------ --------------------------- 3.4/11.0 MB 22.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.7/11.0 MB 11.4 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/11.0 MB 9.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.0 MB 8.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.9/11.0 MB 7.4 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.0 MB 6.9 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 6.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/11.0 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 5.1 MB/s eta 0:00:01
# ...

# %%
import pandas as pd, time, re

# %%
import numpy as np

# %%
import os, re, datetime
